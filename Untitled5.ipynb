# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a193-cloud/python/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Create a sample DataFrame with student data and roll numbers
data = {'Roll Number': [101, 102, 103, 104, 105],
        'Student Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve']}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
file_path = 'student_data.csv'
df.to_csv(file_path, index=False)

print(f"CSV file '{file_path}' created successfully.")
