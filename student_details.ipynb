# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a193-cloud/python/blob/main/student_details.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- Student Details ---
name = input("Enter Student Name: ")
roll = input("Enter Roll Number: ")
num_subjects = int(input("Enter Number of Subjects: "))
subjects = []
for i in range(num_subjects):
    print(f"\n--- Subject {i+1} ---")
    subject_name = input("Enter Subject Name: ")
    internal1 = int(input("Internal-1 Marks : "))
    internal2 = int(input("Internal-2 Marks : "))
    assignment = int(input("Assignment Marks : "))
    external = int(input("External Exam Marks : "))
    # Internal marks (out of 40)
    avg_internal = (internal1 + internal2) / 2
    internal_total = avg_internal + assignment
    # External marks (out of 60)
    external_total = (external / 100) * 60
    # Final total (out of 100)
    final_total = internal_total + external_total
    # --- Grade function in the middle ---
    def calculate_grade(total_marks):
        if total_marks >= 90:
            return "O"
        elif total_marks >= 80:
            return "A+"
        elif total_marks >= 70:
            return "A"
        elif total_marks >= 60:
            return "B+"
        elif total_marks >= 50:
            return "B"
        elif total_marks >= 40:
            return "C"
        else:
            return "F"
    grade = calculate_grade(final_total)
    # Pass/Fail check
    if internal_total < 20 or external_total < 30:
        result = "FAIL"
        grade = "F"
    else:
        result = "PASS"
    subjects.append([subject_name, internal_total, external_total, final_total, result, grade])
# --- Print Marksheet ---
print("\n==============================")
print(" MARKSHEET")
print("==============================")
print(f"Name : {name}")
print(f"Roll : {roll}")
print("------------------------------")
print(f"{'Subject':<15}{'Internal(40)':<15}{'External(60)':<15}{'Total(100)':<15}{'Result':<10}{'Grade':<5}")
print("-"*75)
for sub in subjects:
    print(f"{sub[0]:<15}{sub[1]:<15.2f}{sub[2]:<15.2f}{sub[3]:<15.2f}{sub[4]:<10}{sub[5]:<5}")
print("="*75)
# Out:
# Enter Student Name: pradeep reddy
# Enter Roll Number: 193
# Enter Number of Subjects: 3
#
# --- Subject 1 ---
# Enter Subject Name: m1
# Internal-1 Marks : 25
# Internal-2 Marks : 20
# Assignment Marks : 12
# External Exam Marks : 78
#
# --- Subject 2 ---
# Enter Subject Name: python
# Internal-1 Marks : 25
# Internal-2 Marks : 29
# Assignment Marks : 10
# External Exam Marks : 90
#
# --- Subject 3 ---
# Enter Subject Name: dsa
# Internal-1 Marks : 22
# Internal-2 Marks : 26
# Assignment Marks : 10
# External Exam Marks : 80
#
# ==============================
#  MARKSHEET
# ==============================
# Name : pradeep reddy
# Roll : 193
# ------------------------------
# Subject        Internal(40)   External(60)   Total(100)     Result    Grade
# ---------------------------------------------------------------------------
# m1             34.50          46.80          81.30          PASS      A+
# python         37.00          54.00          91.00          PASS      O
# dsa            34.00          48.00          82.00          PASS      A+
# ===========================================================================
